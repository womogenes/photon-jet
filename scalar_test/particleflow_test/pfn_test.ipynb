# %% [markdown]
# # Particle Flow Test 1
#
# Make our own particle flow network, train it on photon jets

# %%
# Up to a couple minutes to import everything

# Computing imports
print(f"Importing computing things...")
import os
import numpy as np

print(f"Importing tensorflow... (this could take a while)")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2" # Make tensorflow quieter
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay

# Useful imports
print(f"Importing display things...")
from tqdm import tqdm
import matplotlib.pyplot as plt

# Energyflow imports
print(f"Importing energyflow things...")
from energyflow.utils import data_split, to_categorical

# Own imports
from utils import convert_size
# Out:
# Importing computing things...
# Importing tensorflow... (this could take a while)
# Importing display things...
# Importing energyflow things...

# %% [markdown]
# ## Import, preprocess data
#
# Data lives in `X_train`, `X_val`, `X_test`, and `Y_train`, `Y_val`, `Y_test`.

# %%
# ~10 sec
jets_path = "/usatlas/atlas01/atlasdisk/users/atlas_wifeng/photon-jet/data/processed/scalar_test/all_jets_7_feature_point_cloud.npz"
jets = np.load(jets_path)

X, y = jets["X"], jets["y"]
Y = to_categorical(y)

print("Loaded data")
# Out:
# Loaded data

# %%
print(X.shape)
print(Y.shape)
# Out:
# (300000, 960, 7)
# (300000, 3)

# %%
# ~5 sec
# Do train/val/test split
N = len(X)
n_val = int(0.1 * N)
n_test = int(0.1 * N)

(X_train, X_val, X_test,
 Y_train, Y_val, Y_test) = data_split(X, Y, val=n_val, test=n_test)

print("Done train/val/test split")
# Out:
# Done train/val/test split

# %% [markdown]
# ## Define the model

# %% [markdown]
# PFN model:
# $$\text{PFN}=F\left(\sum_{i=1}^M \Phi(p_i)\right)$$

# %%
def PFN(n_features,
        n_particles,
        n_outputs,
        Phi_sizes,
        F_sizes,
        name=None):
    
        inputs = layers.Input((n_particles, n_features), name="input")    
        masking_layer = layers.Masking(
            mask_value=0.,
            input_shape=(n_particles, n_features)
        )
        Phi_layers = [layers.Dense(size, activation="relu", name=f"Phi_{i}") for i, size in enumerate(Phi_sizes)]
        F_layers = [layers.Dense(size, activation="relu", name=f"F_{i}") for i, size in enumerate(F_sizes)]
        last_layer = layers.Dense(n_outputs, name="output")
        
        x = masking_layer(inputs)
        for layer in Phi_layers:
            x = layers.TimeDistributed(layer)(x)
        x = tf.math.reduce_sum(x, axis=1)
        for layer in F_layers:
            x = layer(x)
        x = last_layer(x)
        
        return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ## Compile and train the model

# %%
try:
    del fit_history
    del model
except NameError:
    pass

tf.keras.backend.clear_session()

# %%
memory_usage = tf.config.experimental.get_memory_info("GPU:0")
print("GPU memory usage")
print(f"  current: {convert_size(memory_usage['current'])}")
print(f"  peak:    {convert_size(memory_usage['peak'])}")
# Out:
# GPU memory usage
#   current: 4.58 GB
#   peak:    4.58 GB

# %%
# Takes about 5 sec the first time
# Data dimensions
n_features = 7
n_particles = 960

model = PFN(
    n_features=n_features,
    n_particles=n_particles,
    n_outputs=3,
    Phi_sizes=(128,) * 4 + (64,) * 3,
    F_sizes=(128,) * 4 + (64,) * 3
)

# %%
lr = 2e-3

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

# %%
fit_history = model.fit(X_train, Y_train,
                        epochs=15,
                        batch_size=100,
                        validation_data=(X_val, Y_val),
                        verbose=1)
# Out:
# Epoch 1/15
# 2400/2400 [==============================] - 53s 20ms/step - loss: 1.1940 - accuracy: 0.4541 - val_loss: 0.9883 - val_accuracy: 0.4824
# Epoch 2/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.9909 - accuracy: 0.4848 - val_loss: 0.9937 - val_accuracy: 0.4861
# Epoch 3/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.9391 - accuracy: 0.5195 - val_loss: 0.8460 - val_accuracy: 0.5876
# Epoch 4/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.8520 - accuracy: 0.5821 - val_loss: 0.7329 - val_accuracy: 0.6580
# Epoch 5/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.8773 - accuracy: 0.5714 - val_loss: 0.9881 - val_accuracy: 0.4751
# Epoch 6/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.9206 - accuracy: 0.5316 - val_loss: 0.7304 - val_accuracy: 0.6713
# Epoch 7/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.6395 - accuracy: 0.7129 - val_loss: 0.5316 - val_accuracy: 0.7755
# Epoch 8/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.6494 - accuracy: 0.7060 - val_loss: 0.4549 - val_accuracy: 0.8158
# Epoch 9/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.4233 - accuracy: 0.8289 - val_loss: 0.4880 - val_accuracy: 0.7921
# Epoch 10/15
# 2400/2400 [==============================] - 47s 19ms/step - loss: 0.5498 - accuracy: 0.7636 - val_loss: 0.4435 - val_accuracy: 0.8197
# Epoch 11/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.5303 - accuracy: 0.7709 - val_loss: 0.5245 - val_accuracy: 0.7741
# Epoch 12/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.5845 - accuracy: 0.7441 - val_loss: 0.5164 - val_accuracy: 0.7769
# Epoch 13/15
# 2400/2400 [==============================] - 48s 20ms/step - loss: 0.5616 - accuracy: 0.7552 - val_loss: 0.5138 - val_accuracy: 0.7784
# Epoch 14/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.7233 - accuracy: 0.6823 - val_loss: 0.6584 - val_accuracy: 0.7089
# Epoch 15/15
# 2400/2400 [==============================] - 47s 20ms/step - loss: 0.5751 - accuracy: 0.7495 - val_loss: 0.5099 - val_accuracy: 0.7883

# %%
# ~5 sec
# model.save("/usatlas/atlas01/atlasdisk/users/atlas_wifeng/photon-jet/models/pfn/85pc_.model")

# %%
plt.plot(fit_history.history['accuracy'])
plt.plot(fit_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(fit_history.history['loss'][1:])
plt.plot(fit_history.history['val_loss'][1:])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# get predictions on test data
preds = model.predict(X_test, batch_size=500)
# Out:
# 60/60 [==============================] - 2s 32ms/step

# %%
test_labels = np.argmax(Y_test, axis=1)
pred_labels = np.argmax(preds, axis=1)

mask = (test_labels == pred_labels).astype(float)
print(mask)
print(f"Test accuracy: {mask.mean()}")
# Out:
# [1. 1. 1. ... 1. 0. 0.]
# Test accuracy: 0.7882333333333333

# %%
cm = confusion_matrix(test_labels, pred_labels).astype(float)
cm /= np.sum(cm, axis=1, keepdims=True)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["pion", "photon", "scalar"]
);
disp.plot(cmap="Blues");

print(f"Total test jets: {len(test_labels)}")
# Out:
# Total test jets: 30000
